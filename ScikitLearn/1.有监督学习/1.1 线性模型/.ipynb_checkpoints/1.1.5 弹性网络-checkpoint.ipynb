# %% [markdown]
# ElasticNet 是一个训练时同时用 l1 和 l2 范数进行正则化的线性回归模型。

# %% [markdown]
# 这种组合允许学习稀疏模型，其中很少有权重是非零类，就像 Lasso，同时仍然保持 Ridge 的正则化性质。我们可以通过 l1_radio 参数控制 l1 和 l2范数的组合。

# %% [markdown]
# 当多个特征存在相关时，弹性网是很有用的。Lasso 很可能随机挑选其中之一，而弹性网则可能兼而有之。

# %% [markdown]
# 让Lasso 和 Ridge 进行交互的一个切实的优势是， 它允许弹性网在循环过程中继承 Ridge的一些稳定性。
#
# 在这种情况下，要最小化的目标函数是：

# %% [markdown]
# ![image.png](attachment:0eb6fd2a-c874-494f-9b50-035811c2d354.png)

# %% [markdown]
# ElasticNetCV 类可以通过交叉验证来设置参数 alpha （α） 和 l1_radio （p）
